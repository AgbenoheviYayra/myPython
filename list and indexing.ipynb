# %%
names = ["Esi","Amoah","Eben","Asirifi","Betty"]

# %%
(names[2])
# Out:
# 'Eben'

# %%
len(names)
# Out:
# 5

# %%
names.append("Erica")

# %%
print(names)
# Out:
# ['Esi', 'Amoah', 'Eben', 'Asirifi', 'Betty', 'Erica']

# %%
names.remove("Betty")

# %%
names[1:3]
# Out:
# ['Amoah', 'Eben']
